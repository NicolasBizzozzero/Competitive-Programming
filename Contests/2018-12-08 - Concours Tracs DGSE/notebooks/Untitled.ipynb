# %%
import json
import csv
from pprint import pprint


PATH_FILE_JSON = "../data/wifi/Liste-Wifi"
PATH_FILE_TSV = "../data/wifi/Liste-Password"
PATH_FILE_OUTPUT = "../output/wifi.csv"

# %%
id_hash = dict()
hash_clear = dict()
id_clear = dict()


with open(PATH_FILE_JSON) as file:
    for w in json.load(file):
        id_hash[w["ap"]] = w["hash"]
        id_clear[w["ap"]] = None


with open(PATH_FILE_TSV) as file:
    reader = csv.reader(file, delimiter=" ")

    for line in reader:
        hash_clear[line[0]] = line[1]

hash_test = dict()
for k, v in hash_clear.items():
    hash_test[k] = v.replace("urhs", "").replace(
        "tye", "").replace("lqx", "").replace("x", "").replace("niz", "").replace("um", "")


pprint(hash_test)

for (id, hash) in id_hash.items():
    try:
        id_clear[id] = hash_clear[hash]
    except KeyError:
        pass


# with open(PATH_FILE_OUTPUT, "w") as output:
#     writer = csv.writer(output, delimiter=";")

#     for (id, clear) in id_clear.items():
#         writer.writerow([id, clear])
# Out:
# {'00c9635cd11e3d8e9f41d594902cdcd9020ac10c56f10c444f18467bf1ec97b0': 'tpftpfgztpfelrt',
#  '00d719ec33bdb69bd22f8c4e9d1ee8d160870407e21659ee0e4715e5f8b0ceb3': 'tpfkukwb',
#  '01b7abb43963b8a977dadd670bf6785c84fe19ffeb13dd2cd7bc7e2aa375894c': 'elrthtpfjbz',
#  '03707c1646282ba59a08e1ba5e79675d6f4333a4aa8d1f96c2cc389d3d7b582c': 'ptumh',
#  '057ac1c7cc6cda6d017ef5cb9b5b94fafc1d62b16f57edec78184247f8f1856a': 'kwbbzumum',
#  '08e1e01d09b1255ea125d621c2794fafed03961f6854ba8778b7ec8932efa138': 'fptjelrt',
#  '09312c4bd769bb99df0c463faefbac0f1334469b1c8a0e20ab2f1dac0cf98acd': 'kugztpfelrth',
#  '0e92550aa95812e869cd2228d0131c3ddb3043b7452a129d881ec36720518f89': 'fgzbzkukwb',
#  '10d19ed3093042622ea2b40fb7577e08f6acb7c10fdb92c3340a7cf5a72bb88f': 'tpfumpttpf',
#  '12aad647985ed806593ab6b75e7340b07cc23183c5abf7595b11eb68f827a544': 'tpfum',
#  '136f03b65ccacdb86a2cd10115f17e334c9b5ce901321b4f99becbc609a24ee4': 'kuelrtelrttpfkwbgz',
#  '13a58043be5d04a6038504a4f10fd4543adbcf14bd5cfc073b16bc59bd15c33e': 'gzjkuum',
#  '171d1c18bbfb28d46a96131a525a3bd2dafa2f5dec07f44bc3604bc3d003cd48': 'jkwbfelrt',
#  '21c1649e312fbbb03a3fda6ef48d48accd018e0fa0825f1fdc3e830b1b81d57a': 'tpfkwbkubzelrt',
#  '2383c00f914df17853b7abf736dfd631fe58f15946d2ed22549a68cd3d233c10': 'kutpfumpt',
#  '23c559b1d7ed6b299d8788d49df34694fe956fd12b7a4fe5d8cd87a72873fd3b': 'umfelrtum',
#  '23ff676bca1a4728a20884f71284f3a44c2a57f453a5d7c8086f529221fbeb97': 'bzgzgzkwbgztpf',
#  '2afb50adabbdc3463561e3fcfba017018f2095df2dedf223cf08d2ca09db1a74': 'tpfgzh',
#  'b73d4d687cafde0475f6cf7bfa4b1395d4c32ba5256f47f4d747ef45b8e5c0a2': 'bzbzelrtptkwb',
#  'b8ca85aefb54a7f9b010ec7dbdd49048f36830ef77bba3a50e8e3fda25227f14': 'umumumpttpf',
#  'ba3bc56b0df0918d8c418ff8e3f8dec61558eedd4e14d59e4d5b142685c9e84c': 'kwbhfelrtkwb',
#  'bb9e9f0ed0911118ff72f65cbf5a2192e43e9cc1beb0f71dc792955b2387d909': 'gzpthku',
#  'be08cc6c4aab7bc5899ed7ccd3edb4d63cab64956a1232931a5561487aad449c': 'gzbzbztpf',
#  'be40a79167015b6f1003b528d54e9b556b42324f403eabfec8e795851cb2a9f9': 'tpfjkwbptgz',
#  'c48c9651e965a03e1c3d2627bfad829bf11a17ef078ef2f480a80528dd60e364': 'gzumgzgzelrt',
#  'c7380b8ee5460abd2fff9f22b937c1280a8dbe3a870f115103fe44d9173481de': 'tpffh',
#  'c84f0296e95267f6a5c55a44d7fb61ea9d5530488b467b4dc7ea17b0b1d0e43d': 'kwbjj',
#  'c9daeefa310e4f6d2235a63bd1804731b168c3f2b4b50b1d9d3162e037a65883': 'ptumbzumptf',
#  'ca7262795e62e07b2344637829bcf15041c951edfead0a17ca0060a1dd58ba89': 'umtpfj',
#  'cf47985dd05ae2aa02a292015c6a31f95119422a41601d30534a49c12c38be73': 'tpfkugzku',
#  'd3c2de3839d598c7b8c5b1a2a4117af2237b68c92d4c9fb084c9157a04d12e8c': 'kugzhgzku',
#  'd421b3a4b33b976b0fbed6374657b0a0511cd2b611af49e55faeb20fef1f917b': 'bzkugz',
#  'd4b62c016f90cf6e3f95e2274dd31bc0401991b5154dd43a914c83f964a4ed9b': 'kwbjelrt',
#  'd9a22b175d464371aa23c826fb951ec56dd8b1c77c6a255bbf7e82fa6cec37d4': 'kujbzku',
#  'daced8127b0255053969e9982d632c3bba5af400f06b11924a1a3848c6273e13': 'kwbhgztpfh',
#  'dc2ccd96ce8f3dad62b5bee402ea04e3d0d3b37553d03184d813f0fb3042136d': 'hhjkwbum',
#  'dcd23a999de908037ffa001665db11bb901e41a76fd65014a39235ffe16969ad': 'umgz',
#  'e2e7da1e1d827534cec4b9a6e3641f4b152ae0baa9b06f5d29e049e0e7dec7d1': 'hjbzumkwb',
#  'e3c8c880a953813e3baea565b18212462c537c9aacb0eb79090ec5fbf19883f3': 'bzkwbhumh',
#  'ea17f9aa6d1b4dd44004e14550964af3a5062ea89641ae52b18d51d5a95c40cf': 'jelrttpf',
#  'efd65df01986438fb6919414077bee19c9a0bdf77e52a31f58855765ca973724': 'kwbjhumptelrt',
#  'f6120f528e3dfca99bf091524f0b56dde215543978c7f57b218dce5f5e7aace2': 'kwbkwbkukuum',
#  'f9a1724c5eb89d429826ac9d293eea3b7d023656c32b707190bb380be97f0816': 'kuelrtelrt',
#  'fcce7d55906922ab3372256e76b19909c61871860395ab415e5fa1acf5fd5672': 'gztpftpfpt',
#  'fdf8276af0622a2abf8729f2eb098d42bf948dce726a534b6d74411882487a22': 'umjtpfumelrt'}
